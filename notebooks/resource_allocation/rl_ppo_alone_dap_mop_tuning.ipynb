# %%
import pandas as pd
import torch
df = pd.read_csv("../../data/narc_data/expanded_fertilizer_recommendations.csv", index_col=0 )

# %%
df.head()
# Out:
#           lon    ph organic_matter total_nitrogen     potassium         p2o5  \
# lat
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
#
#           boron      zinc     sand     clay  ...                      palika  \
# lat                                          ...
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
#
#         crop variety UREA1 UREA2 UREA3   DAP   MOP  organic  boron_fert
# lat
# 27.65  Maize     OPV  1.55  2.90  2.90  3.47  2.23       10         1.5
# 27.65  Maize  Hybrid  2.50  3.62  3.62  2.89  3.34       10         1.5
# 27.65   Rice     OPV  2.50  3.62  3.62  2.89  3.34        6         1.0
# 27.65   Rice  Hybrid  2.50  3.62  3.62  2.89  3.34        6         1.0
# 27.65  Wheat     OPV  2.50  3.62  3.62  2.89  2.78        6         1.5
#
# [5 rows x 24 columns]

# %%
df.head()
# Out:
#           lon    ph organic_matter total_nitrogen     potassium         p2o5  \
# lat
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
# 27.65  83.837  6.37         2.69 %         0.12 %  187.76 kg/ha  66.41 kg/ha
#
#           boron      zinc     sand     clay  ...                      palika  \
# lat                                          ...
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
# 27.65  1.05 ppm  1.76 ppm  48.71 %  14.92 %  ...  Binayee tribeni Gaunpalika
#
#         crop variety UREA1 UREA2 UREA3   DAP   MOP  organic  boron_fert
# lat
# 27.65  Maize     OPV  1.55  2.90  2.90  3.47  2.23       10         1.5
# 27.65  Maize  Hybrid  2.50  3.62  3.62  2.89  3.34       10         1.5
# 27.65   Rice     OPV  2.50  3.62  3.62  2.89  3.34        6         1.0
# 27.65   Rice  Hybrid  2.50  3.62  3.62  2.89  3.34        6         1.0
# 27.65  Wheat     OPV  2.50  3.62  3.62  2.89  2.78        6         1.5
#
# [5 rows x 24 columns]

# %%
df = df[df['crop'].str.lower() != 'maize'].reset_index(drop=True)

# %%
df = df[df['crop'].str.lower() != 'wheat'].reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['lon', 'ph', 'organic_matter', 'total_nitrogen', 'potassium', 'p2o5',
#        'boron', 'zinc', 'sand', 'clay', 'slit', 'parentsoil', 'province',
#        'district', 'palika', 'crop', 'variety', 'UREA1', 'UREA2', 'UREA3',
#        'DAP', 'MOP', 'organic', 'boron_fert'],
#       dtype='object')

# %%
df['crop'].unique()
# Out:
# array(['Rice'], dtype=object)

# %%
# df.drop(columns='palika_num', inplace=True)
df.drop(columns='district', inplace=True)
df.drop(columns='province', inplace=True)
df.drop(columns='palika', inplace=True)
df.drop(columns='crop', inplace=True)
df.drop(columns='parentsoil', inplace=True)
df.drop(columns='variety', inplace=True)

# %%
import numpy as np

# %%
# Convert the relevant columns to string type before applying str.replace
df['ph'] = df['ph'].astype(str).str.replace('%', '', regex=False)
df['organic_matter'] = df['organic_matter'].astype(str).str.replace('%', '', regex=False)
df['total_nitrogen'] = df['total_nitrogen'].astype(str).str.replace('%', '', regex=False)

# Remove 'ppm' from boron and zinc
df['boron'] = df['boron'].astype(str).str.replace('ppm', '', regex=False)
df['zinc'] = df['zinc'].astype(str).str.replace('ppm', '', regex=False)

# Remove 'kg/ha' from potassium and p2o5
df['potassium'] = df['potassium'].astype(str).str.replace('kg/ha', '', regex=False)
df['p2o5'] = df['p2o5'].astype(str).str.replace('kg/ha', '', regex=False)

# Remove '%' from sand, clay, and slit columns (if necessary)
df['sand'] = df['sand'].astype(str).str.replace('%', '', regex=False)
df['clay'] = df['clay'].astype(str).str.replace('%', '', regex=False)
df['slit'] = df['slit'].astype(str).str.replace('%', '', regex=False)

# Convert columns to appropriate numeric types (float or int)
df['ph'] = df['ph'].astype(float)
df['organic_matter'] = df['organic_matter'].astype(float)

df['boron'] = df['boron'].astype(float)
df['total_nitrogen'] = df['total_nitrogen'].astype(float)
df['boron_fert'] = df['boron_fert'].astype(float)

df['zinc'] = df['zinc'].astype(float)
# df['zinc_fert'] = df['zinc_fert'].astype(float)
df['organic'] = df['organic'].astype(float)

df['potassium'] = df['potassium'].astype(float)
df['p2o5'] = df['p2o5'].astype(float)
df['sand'] = df['sand'].astype(float)
df['clay'] = df['clay'].astype(float)
df['slit'] = df['slit'].astype(float)
df['UREA1'] = df['UREA1'].astype(float)


df['UREA2'] = df['UREA2'].astype(float)

df['UREA3'] = df['UREA3'].astype(float)

df['DAP'] = df['DAP'].astype(float)
df['MOP'] = df['MOP'].astype(float)


# Now your columns are cleaned and converted to numeric types for further processing
print(df.head())
# Out:
#       lon    ph  organic_matter  total_nitrogen  potassium   p2o5  boron  \
# 0  83.837  6.37            2.69            0.12     187.76  66.41   1.05
# 1  83.837  6.37            2.69            0.12     187.76  66.41   1.05
# 2  83.836  6.34            2.62            0.12     183.54  60.75   1.05
# 3  83.836  6.34            2.62            0.12     183.54  60.75   1.05
# 4  83.843  6.27            2.52            0.11     160.65  49.49   1.04
#
#    zinc   sand   clay   slit  UREA1  UREA2  UREA3   DAP   MOP  organic  \
# 0  1.76  48.71  14.92  37.48   2.50   3.62   3.62  2.89  3.34      6.0
# 1  1.76  48.71  14.92  37.48   2.50   3.62   3.62  2.89  3.34      6.0
# 2  1.82  48.83  14.72  37.95   2.50   3.62   3.62  2.89  3.34      6.0
# 3  1.82  48.83  14.72  37.95   2.50   3.62   3.62  2.89  3.34      6.0
# 4  1.62  46.90  13.91  35.77   2.21   3.62   3.62  3.62  3.34      6.0
#
#    boron_fert
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0

# %%
df.head()
# Out:
#       lon    ph  organic_matter  total_nitrogen  potassium   p2o5  boron  \
# 0  83.837  6.37            2.69            0.12     187.76  66.41   1.05
# 1  83.837  6.37            2.69            0.12     187.76  66.41   1.05
# 2  83.836  6.34            2.62            0.12     183.54  60.75   1.05
# 3  83.836  6.34            2.62            0.12     183.54  60.75   1.05
# 4  83.843  6.27            2.52            0.11     160.65  49.49   1.04
#
#    zinc   sand   clay   slit  UREA1  UREA2  UREA3   DAP   MOP  organic  \
# 0  1.76  48.71  14.92  37.48   2.50   3.62   3.62  2.89  3.34      6.0
# 1  1.76  48.71  14.92  37.48   2.50   3.62   3.62  2.89  3.34      6.0
# 2  1.82  48.83  14.72  37.95   2.50   3.62   3.62  2.89  3.34      6.0
# 3  1.82  48.83  14.72  37.95   2.50   3.62   3.62  2.89  3.34      6.0
# 4  1.62  46.90  13.91  35.77   2.21   3.62   3.62  3.62  3.34      6.0
#
#    boron_fert
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0

# %%
print(df['DAP'].describe())
print(df['MOP'].describe())
print(df['UREA1'].describe())
# Out:
# count    278966.000000
# mean          2.018781
# std           0.791509
# min           0.540000
# 25%           1.630000
# 50%           2.170000
# 75%           2.170000
# max           3.620000
# Name: DAP, dtype: float64
# count    278966.000000
# mean          2.022141
# std           0.696524
# min           0.420000
# 25%           1.670000
# 50%           1.670000
# 75%           2.500000
# max           3.340000
# Name: MOP, dtype: float64
# count    278966.000000
# mean          1.471450
# std           0.669755
# min          -0.500000
# 25%           1.090000
# 50%           1.310000
# 75%           1.770000
# max           3.270000
# Name: UREA1, dtype: float64

# %%
df['crop'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crop'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['crop'].unique()
#
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'crop'

# %%
# ==========================================================
# PPO FROM SCRATCH FOR FERTILIZER RECOMMENDATION (NARC)
# Saves BEST model based on LOWEST VALIDATION RMSE
# Targets: UREA, DAP, MOP (kg/ropani)
# ==========================================================

import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, r2_score
import random

# ==========================================================
# REPRODUCIBILITY & DEVICE
# ==========================================================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

EPS = 1e-8

# ==========================================================
# LOAD DATA
# ==========================================================

fert_cols = ["UREA1", "DAP", "MOP"]

# Encode categorical variables
for col in ["crop", "variety", "parentsoil"]:
    if col in df.columns:
        df[col] = LabelEncoder().fit_transform(df[col].astype(str))

# Manually select features you want to use for training
feature_cols = [
    'ph',
    'organic_matter',
    'total_nitrogen',
    'p2o5',
    'potassium',
    'boron',
    'zinc',
    'sand',
    'clay',
    'slit',
    'boron'
]

# Optional: if your dataset has extra columns, make sure to only pick existing ones
feature_cols = [col for col in feature_cols if col in df.columns]
X = df[feature_cols].values
y = df[fert_cols].values   # real units (kg/ropani)
# Out:
# Device: cuda

# %%
df.head()
# Out:
#       lon    ph  organic_matter  total_nitrogen  potassium   p2o5  boron  \
# 0  83.837  6.37            2.69            0.12     187.76  66.41   1.05
# 1  83.837  6.37            2.69            0.12     187.76  66.41   1.05
# 2  83.836  6.34            2.62            0.12     183.54  60.75   1.05
# 3  83.836  6.34            2.62            0.12     183.54  60.75   1.05
# 4  83.843  6.27            2.52            0.11     160.65  49.49   1.04
#
#    zinc   sand   clay   slit  UREA1  UREA2  UREA3   DAP   MOP  organic  \
# 0  1.76  48.71  14.92  37.48   2.50   3.62   3.62  2.89  3.34      6.0
# 1  1.76  48.71  14.92  37.48   2.50   3.62   3.62  2.89  3.34      6.0
# 2  1.82  48.83  14.72  37.95   2.50   3.62   3.62  2.89  3.34      6.0
# 3  1.82  48.83  14.72  37.95   2.50   3.62   3.62  2.89  3.34      6.0
# 4  1.62  46.90  13.91  35.77   2.21   3.62   3.62  3.62  3.34      6.0
#
#    boron_fert
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0

# %%
df.head()
# Out:
#       lon    ph  organic_matter  total_nitrogen  potassium   p2o5  boron  \
# 0  83.837  6.37            2.69            0.12     187.76  66.41   1.05
# 1  83.837  6.37            2.69            0.12     187.76  66.41   1.05
# 2  83.836  6.34            2.62            0.12     183.54  60.75   1.05
# 3  83.836  6.34            2.62            0.12     183.54  60.75   1.05
# 4  83.843  6.27            2.52            0.11     160.65  49.49   1.04
#
#    zinc   sand   clay   slit  UREA1  UREA2  UREA3   DAP   MOP  organic  \
# 0  1.76  48.71  14.92  37.48   2.50   3.62   3.62  2.89  3.34      6.0
# 1  1.76  48.71  14.92  37.48   2.50   3.62   3.62  2.89  3.34      6.0
# 2  1.82  48.83  14.72  37.95   2.50   3.62   3.62  2.89  3.34      6.0
# 3  1.82  48.83  14.72  37.95   2.50   3.62   3.62  2.89  3.34      6.0
# 4  1.62  46.90  13.91  35.77   2.21   3.62   3.62  3.62  3.34      6.0
#
#    boron_fert
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0

# %%
print("Features used in X_train:")
for i, col in enumerate(feature_cols):
    print(f"{i:02d}: {col}")
# Out:
# Features used in X_train:
# 00: ph
# 01: organic_matter
# 02: total_nitrogen
# 03: p2o5
# 04: potassium
# 05: boron
# 06: zinc
# 07: sand
# 08: clay
# 09: slit
# 10: boron

# %%
print("Features shape:", X.shape)
print("Targets shape:", y.shape)
# Out:
# Features shape: (278966, 11)
# Targets shape: (278966, 3)

# %%
# ==========================================================
# SCALE INPUTS ONLY

# ==========================================================
X = X.cpu().numpy() if torch.is_tensor(X) else X  # if X is already a tensor, bring to CPU

scaler_X = StandardScaler()
X = scaler_X.fit_transform(X)

X = torch.tensor(X, dtype=torch.float32, device=device)
y = torch.tensor(y, dtype=torch.float32, device=device)

# ==========================================================
# TRAIN / VALIDATION / TEST SPLIT
# ==========================================================
perm = torch.randperm(len(X))
n = len(X)
train_end = int(0.7 * n)
val_end = int(0.85 * n)

X_train, y_train = X[perm[:train_end]], y[perm[:train_end]]
X_val, y_val     = X[perm[train_end:val_end]], y[perm[train_end:val_end]]
X_test, y_test   = X[perm[val_end:]], y[perm[val_end:]]

state_dim = X_train.shape[1]
action_dim = 3

# ==========================================================
# ACTION BOUNDS (kg/ropani)
# ==========================================================
FERT_MIN = torch.tensor([0.0, 0.5, 0.4], device=device)
FERT_MAX = torch.tensor([3.3, 4.4, 3.4], device=device)

# ==========================================================
# PPO HYPERPARAMETERS
# ==========================================================
hidden_dim = 256
lr_actor = 1e-4
lr_critic = 5e-4
clip_eps = 0.2
ppo_epochs = 10
steps_per_update = 2048
mini_batch = 64
entropy_coef = 0.005
max_grad_norm = 0.5
num_updates = 1500
EPS = 1e-8

# ==========================================================
# ACTOR & CRITIC
# ==========================================================
class Actor(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
        )
        self.mu = nn.Linear(hidden_dim, action_dim)
        self.log_std = nn.Parameter(torch.ones(action_dim) * -0.5)

    def forward(self, x):
        h = self.net(x)
        mu = self.mu(h)
        std = torch.exp(self.log_std)
        return mu, std

class Critic(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1),
        )

    def forward(self, x):
        return self.net(x)

actor = Actor().to(device)
critic = Critic().to(device)

opt_actor = optim.Adam(actor.parameters(), lr=lr_actor)
opt_critic = optim.Adam(critic.parameters(), lr=lr_critic)

# ==========================================================
# IMPROVED REWARD FUNCTION (Weighted Squared Error)
# ==========================================================
weights = torch.tensor([1.0, 1.2, 1.3], device=device)  # slightly higher for DAP/MOP
def reward_fn(pred, truth):
    return -(weights * (pred - truth)**2).sum(dim=1, keepdim=True)

# ==========================================================
# RMSE EVALUATION (PER ACTION)
# ==========================================================
@torch.no_grad()
def eval_rmse(X, y):
    mu, _ = actor(X)
    a = torch.tanh(mu)
    a_real = FERT_MIN + (a + 1) / 2 * (FERT_MAX - FERT_MIN)
    # Clip to valid range
    a_real = torch.clamp(a_real, FERT_MIN, FERT_MAX)
    rmse = torch.sqrt(((a_real - y) ** 2).mean(dim=0))
    return rmse

# ==========================================================
# CHECKPOINT SETUP
# ==========================================================
best_val_rmse = float("inf")
best_update = -1
save_dir = "final_ppo_model"
os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, "ppo_dap_checkjach_best.pt")

# ==========================================================
# PPO TRAINING LOOP
# ==========================================================
for update in range(1, num_updates + 1):

    S, A, R, V, LP = [], [], [], [], []

    # ------------------ ROLLOUT ------------------
    while len(S) * mini_batch < steps_per_update:
        idx = torch.randint(0, len(X_train), (mini_batch,))
        s = X_train[idx]
        t = y_train[idx]

        with torch.no_grad():
            mu, std = actor(s)
            dist = Normal(mu, std)

            raw_a = dist.rsample()
            a = torch.tanh(raw_a)
            a_real = FERT_MIN + (a + 1) / 2 * (FERT_MAX - FERT_MIN)
            a_real = torch.clamp(a_real, FERT_MIN, FERT_MAX)

            logp = dist.log_prob(raw_a).sum(-1, keepdim=True)
            logp -= torch.sum(torch.log(1 - a**2 + EPS), dim=1, keepdim=True)

            v = critic(s)
            r = reward_fn(a_real, t)

        S.append(s); A.append(raw_a)
        R.append(r); V.append(v); LP.append(logp)

    S = torch.cat(S)
    A = torch.cat(A)
    R = torch.cat(R)
    V = torch.cat(V)
    LP = torch.cat(LP)

    # ------------------ ADVANTAGE ------------------
    adv = R - V
    adv = (adv - adv.mean()) / (adv.std() + EPS)

    # ------------------ PPO UPDATE ------------------
    for _ in range(ppo_epochs):
        idx = torch.randperm(len(S))
        for i in range(0, len(S), mini_batch):
            mb = idx[i:i+mini_batch]

            mu, std = actor(S[mb])
            dist = Normal(mu, std)
            entropy = dist.entropy().sum(dim=1).mean()

            new_lp = dist.log_prob(A[mb]).sum(-1, keepdim=True)
            ratio = torch.exp(new_lp - LP[mb])

            surr1 = ratio * adv[mb]
            surr2 = torch.clamp(ratio, 1-clip_eps, 1+clip_eps) * adv[mb]

            actor_loss = -torch.min(surr1, surr2).mean() - entropy_coef * entropy
            critic_loss = nn.MSELoss()(critic(S[mb]), R[mb])

            opt_actor.zero_grad()
            opt_critic.zero_grad()
            actor_loss.backward()
            critic_loss.backward()

            torch.nn.utils.clip_grad_norm_(actor.parameters(), max_grad_norm)
            torch.nn.utils.clip_grad_norm_(critic.parameters(), max_grad_norm)

            opt_actor.step()
            opt_critic.step()

    # ------------------ EVALUATION ------------------
    train_rmse = eval_rmse(X_train, y_train)
    val_rmse   = eval_rmse(X_val, y_val)
    mean_val_rmse = val_rmse.mean().item()

    if mean_val_rmse < best_val_rmse:
        best_val_rmse = mean_val_rmse
        best_update = update

        torch.save({
            "actor_state_dict": actor.state_dict(),
            "critic_state_dict": critic.state_dict(),
            "scaler_X": scaler_X,
            "feature_cols": feature_cols,
            "fert_cols": fert_cols,
            "best_update": update,
            "best_val_rmse": best_val_rmse
        }, save_path)

    if update % 10 == 0:
        print(
            f"[{update:04d}] "
            f"Train RMSE {train_rmse.cpu().numpy()} | "
            f"Val RMSE {val_rmse.cpu().numpy()} | "
            f"BEST Val RMSE {best_val_rmse:.4f} @ update {best_update}"
        )

# ==========================================================
# FINAL EVALUATION ON TEST SET
# ==========================================================
@torch.no_grad()
def eval_metrics(X, y):
    mu, _ = actor(X)
    a = torch.tanh(mu)
    a_real = FERT_MIN + (a + 1) / 2 * (FERT_MAX - FERT_MIN)
    a_real = torch.clamp(a_real, FERT_MIN, FERT_MAX)

    # Convert to CPU numpy arrays to avoid scalar issues
    a_real_np = a_real.cpu().numpy()
    y_np = y.cpu().numpy()

    rmse = np.sqrt(((a_real_np - y_np) ** 2).mean(axis=0))
    mae = np.mean(np.abs(a_real_np - y_np), axis=0)
    r2 = np.array([r2_score(y_np[:, i], a_real_np[:, i]) for i in range(y_np.shape[1])])
    return rmse, mae, r2, a_real_np, y_np
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_33720\502726174.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(y, dtype=torch.float32, device=device)
# [0010] Train RMSE [0.29004997 0.3827439  0.3571243 ] | Val RMSE [0.28941    0.38080648 0.3570868 ] | BEST Val RMSE 0.3424 @ update 10
# [0020] Train RMSE [0.28958413 0.3838921  0.35381988] | Val RMSE [0.2887269  0.38222942 0.35513514] | BEST Val RMSE 0.3339 @ update 16
# [0030] Train RMSE [0.28594485 0.38693348 0.32575437] | Val RMSE [0.28508732 0.38707167 0.3281593 ] | BEST Val RMSE 0.3214 @ update 25
# [0040] Train RMSE [0.26575294 0.35901645 0.31968135] | Val RMSE [0.2653413  0.35946316 0.32238802] | BEST Val RMSE 0.3138 @ update 36
# [0050] Train RMSE [0.27188534 0.32699665 0.31557328] | Val RMSE [0.27135524 0.32781866 0.3194629 ] | BEST Val RMSE 0.3061 @ update 44
# [0060] Train RMSE [0.27255473 0.32815915 0.31277174] | Val RMSE [0.27197468 0.32858127 0.31649652] | BEST Val RMSE 0.2985 @ update 53
# [0070] Train RMSE [0.27680618 0.32472286 0.31608215] | Val RMSE [0.27637076 0.32550302 0.3198275 ] | BEST Val RMSE 0.2985 @ update 53
# [0080] Train RMSE [0.2874591  0.32997808 0.3166962 ] | Val RMSE [0.28724664 0.3304001  0.3197192 ] | BEST Val RMSE 0.2985 @ update 53
# [0090] Train RMSE [0.29693338 0.31527233 0.32948124] | Val RMSE [0.29646388 0.31547484 0.33177787] | BEST Val RMSE 0.2985 @ update 53
# [0100] Train RMSE [0.30047956 0.3131893  0.33146867] | Val RMSE [0.2997515  0.31419715 0.3341691 ] | BEST Val RMSE 0.2985 @ update 53
# [0110] Train RMSE [0.29047462 0.33275148 0.33664116] | Val RMSE [0.28967708 0.33156723 0.3384291 ] | BEST Val RMSE 0.2985 @ update 53
# [0120] Train RMSE [0.28883198 0.33197868 0.34112427] | Val RMSE [0.28922442 0.3315421  0.34342715] | BEST Val RMSE 0.2985 @ update 53
# [0130] Train RMSE [0.27519578 0.3079837  0.34060413] | Val RMSE [0.27514127 0.30897954 0.3433501 ] | BEST Val RMSE 0.2985 @ update 53
# [0140] Train RMSE [0.2666543  0.3091297  0.33553886] | Val RMSE [0.2674658  0.31021845 0.33842123] | BEST Val RMSE 0.2985 @ update 53
# [0150] Train RMSE [0.26802868 0.30951944 0.3284445 ] | Val RMSE [0.26846257 0.3112693  0.3308598 ] | BEST Val RMSE 0.2985 @ update 53
# [0160] Train RMSE [0.28433377 0.33889502 0.33330446] | Val RMSE [0.2840279  0.33880717 0.33542794] | BEST Val RMSE 0.2985 @ update 53
# [0170] Train RMSE [0.28670737 0.33018532 0.34289017] | Val RMSE [0.2865917 0.3306556 0.3445728] | BEST Val RMSE 0.2985 @ update 53
# [0180] Train RMSE [0.2859732  0.37208766 0.33153933] | Val RMSE [0.28593662 0.37215093 0.333223  ] | BEST Val RMSE 0.2985 @ update 53
# [0190] Train RMSE [0.30536094 0.41147447 0.31772307] | Val RMSE [0.30476233 0.40966687 0.3194761 ] | BEST Val RMSE 0.2985 @ update 53
# [0200] Train RMSE [0.29806322 0.39206013 0.30826336] | Val RMSE [0.2969713  0.39070812 0.3100149 ] | BEST Val RMSE 0.2985 @ update 53
# [0210] Train RMSE [0.29989892 0.39116788 0.32710013] | Val RMSE [0.29893953 0.3894225  0.3289925 ] | BEST Val RMSE 0.2985 @ update 53
# [0220] Train RMSE [0.29179162 0.375826   0.32391238] | Val RMSE [0.29056627 0.37489474 0.32650888] | BEST Val RMSE 0.2985 @ update 53
# [0230] Train RMSE [0.2917328  0.3556618  0.34444833] | Val RMSE [0.29017526 0.35618067 0.3463751 ] | BEST Val RMSE 0.2985 @ update 53
# [0240] Train RMSE [0.32829547 0.37350327 0.34687474] | Val RMSE [0.32628468 0.3739687  0.34829172] | BEST Val RMSE 0.2985 @ update 53
# [0250] Train RMSE [0.33404058 0.3793964  0.34432894] | Val RMSE [0.33183697 0.380355   0.3458796 ] | BEST Val RMSE 0.2985 @ update 53
# [0260] Train RMSE [0.33094588 0.3437882  0.3399186 ] | Val RMSE [0.32906592 0.3448858  0.3415664 ] | BEST Val RMSE 0.2985 @ update 53
# [0270] Train RMSE [0.30122292 0.32181546 0.3208597 ] | Val RMSE [0.30028445 0.3223761  0.3229015 ] | BEST Val RMSE 0.2985 @ update 53
# [0280] Train RMSE [0.2965581  0.32201266 0.31852248] | Val RMSE [0.29540506 0.3217693  0.32017463] | BEST Val RMSE 0.2985 @ update 53
# [0290] Train RMSE [0.3014532  0.32066065 0.32029086] | Val RMSE [0.30052736 0.32114097 0.32248515] | BEST Val RMSE 0.2985 @ update 53
# [0300] Train RMSE [0.27982423 0.3142794  0.31427994] | Val RMSE [0.2786085  0.31364506 0.3168628 ] | BEST Val RMSE 0.2985 @ update 53
# [0310] Train RMSE [0.28354788 0.3206802  0.31753755] | Val RMSE [0.28192133 0.3212388  0.32008356] | BEST Val RMSE 0.2985 @ update 53
# [0320] Train RMSE [0.2823146  0.31651455 0.32696894] | Val RMSE [0.2803076 0.3176015 0.3292795] | BEST Val RMSE 0.2985 @ update 53
# [0330] Train RMSE [0.28556672 0.32545462 0.3294731 ] | Val RMSE [0.28338894 0.3270566  0.33163998] | BEST Val RMSE 0.2985 @ update 53
# [0340] Train RMSE [0.28413486 0.32315084 0.33366638] | Val RMSE [0.2823461  0.3238845  0.33553353] | BEST Val RMSE 0.2985 @ update 53
# [0350] Train RMSE [0.28444317 0.33134207 0.3431573 ] | Val RMSE [0.28220567 0.33235323 0.34525055] | BEST Val RMSE 0.2985 @ update 53
# [0360] Train RMSE [0.2788351  0.33834544 0.32569635] | Val RMSE [0.27650294 0.33805346 0.3278664 ] | BEST Val RMSE 0.2985 @ update 53
# [0370] Train RMSE [0.28378117 0.33113894 0.32648557] | Val RMSE [0.28166106 0.33068678 0.32940862] | BEST Val RMSE 0.2985 @ update 53
# [0380] Train RMSE [0.2835545  0.32603094 0.33152726] | Val RMSE [0.2812502  0.32550657 0.33439645] | BEST Val RMSE 0.2985 @ update 53
# [0390] Train RMSE [0.28734    0.35288695 0.34686235] | Val RMSE [0.28482544 0.35093233 0.34905672] | BEST Val RMSE 0.2985 @ update 53
# [0400] Train RMSE [0.28271815 0.346681   0.3395495 ] | Val RMSE [0.2802588  0.3451274  0.34181082] | BEST Val RMSE 0.2985 @ update 53
# [0410] Train RMSE [0.29590794 0.33763206 0.34386167] | Val RMSE [0.29343843 0.33645433 0.3462801 ] | BEST Val RMSE 0.2985 @ update 53
# [0420] Train RMSE [0.29540423 0.3493592  0.3378833 ] | Val RMSE [0.29310286 0.34714645 0.34047326] | BEST Val RMSE 0.2985 @ update 53
# [0430] Train RMSE [0.30325773 0.3588919  0.33893088] | Val RMSE [0.3008806  0.35585505 0.34152192] | BEST Val RMSE 0.2985 @ update 53
# [0440] Train RMSE [0.30350086 0.34793228 0.33550024] | Val RMSE [0.30054203 0.34595874 0.33771744] | BEST Val RMSE 0.2985 @ update 53
# [0450] Train RMSE [0.2982575 0.3397723 0.3260821] | Val RMSE [0.29556003 0.33882067 0.32886025] | BEST Val RMSE 0.2985 @ update 53
# [0460] Train RMSE [0.29562926 0.32841614 0.32039124] | Val RMSE [0.29318553 0.3278329  0.32353538] | BEST Val RMSE 0.2985 @ update 53
# [0470] Train RMSE [0.29577008 0.34099177 0.31945464] | Val RMSE [0.2934941  0.34051254 0.3230851 ] | BEST Val RMSE 0.2985 @ update 53
# [0480] Train RMSE [0.29415494 0.33577242 0.32499063] | Val RMSE [0.29184365 0.3355208  0.32853776] | BEST Val RMSE 0.2985 @ update 53
# [0490] Train RMSE [0.30763325 0.34316504 0.32688147] | Val RMSE [0.3048971  0.34200007 0.3299243 ] | BEST Val RMSE 0.2985 @ update 53
# [0500] Train RMSE [0.31542265 0.34152237 0.3399363 ] | Val RMSE [0.31245485 0.3396445  0.34244856] | BEST Val RMSE 0.2985 @ update 53
# [0510] Train RMSE [0.32353786 0.3515695  0.34735882] | Val RMSE [0.320627   0.34921828 0.35001454] | BEST Val RMSE 0.2985 @ update 53
# [0520] Train RMSE [0.32213244 0.34926966 0.34893072] | Val RMSE [0.31882128 0.3483569  0.35144585] | BEST Val RMSE 0.2985 @ update 53
# [0530] Train RMSE [0.32816777 0.3406111  0.35002378] | Val RMSE [0.3246997  0.34045497 0.35206407] | BEST Val RMSE 0.2985 @ update 53
# [0540] Train RMSE [0.32790515 0.36554208 0.35268986] | Val RMSE [0.32389623 0.36435503 0.35482886] | BEST Val RMSE 0.2985 @ update 53
# [0550] Train RMSE [0.31840217 0.38272685 0.3444372 ] | Val RMSE [0.31418628 0.38148475 0.34684306] | BEST Val RMSE 0.2985 @ update 53
# [0560] Train RMSE [0.31839472 0.37870365 0.35060647] | Val RMSE [0.31501022 0.3771222  0.35305434] | BEST Val RMSE 0.2985 @ update 53
# [0570] Train RMSE [0.31181413 0.37502268 0.33527339] | Val RMSE [0.3095743 0.3729735 0.3381928] | BEST Val RMSE 0.2985 @ update 53
# [0580] Train RMSE [0.3124397 0.3688887 0.3379463] | Val RMSE [0.31018317 0.3669053  0.34060156] | BEST Val RMSE 0.2985 @ update 53
# [0590] Train RMSE [0.31517833 0.36564276 0.33254322] | Val RMSE [0.3129938  0.36361584 0.33552235] | BEST Val RMSE 0.2985 @ update 53
# [0600] Train RMSE [0.31575018 0.3609189  0.33645517] | Val RMSE [0.31324863 0.3591833  0.3393284 ] | BEST Val RMSE 0.2985 @ update 53
# [0610] Train RMSE [0.3141744  0.34124452 0.33887315] | Val RMSE [0.31192315 0.3402924  0.3415176 ] | BEST Val RMSE 0.2985 @ update 53
# [0620] Train RMSE [0.31944907 0.34517622 0.34310368] | Val RMSE [0.3170283  0.34459287 0.34567577] | BEST Val RMSE 0.2985 @ update 53
# [0630] Train RMSE [0.31075162 0.33507618 0.33794832] | Val RMSE [0.30868703 0.33425018 0.34050754] | BEST Val RMSE 0.2985 @ update 53
# [0640] Train RMSE [0.3156006  0.35669637 0.3580113 ] | Val RMSE [0.313389   0.35391024 0.35968843] | BEST Val RMSE 0.2985 @ update 53
# [0650] Train RMSE [0.3346048  0.35940465 0.36294192] | Val RMSE [0.33187297 0.35616243 0.36425444] | BEST Val RMSE 0.2985 @ update 53
# [0660] Train RMSE [0.35448244 0.3558807  0.39484802] | Val RMSE [0.3519708  0.35280958 0.39510077] | BEST Val RMSE 0.2985 @ update 53
# [0670] Train RMSE [0.36342588 0.35249907 0.4022171 ] | Val RMSE [0.3605357  0.34943026 0.40238234] | BEST Val RMSE 0.2985 @ update 53
# [0680] Train RMSE [0.36038664 0.3671305  0.41816667] | Val RMSE [0.35704663 0.36415446 0.4176146 ] | BEST Val RMSE 0.2985 @ update 53
# [0690] Train RMSE [0.36715823 0.3576467  0.41046637] | Val RMSE [0.3642055  0.35544324 0.41003594] | BEST Val RMSE 0.2985 @ update 53
# [0700] Train RMSE [0.35983855 0.35239407 0.3989699 ] | Val RMSE [0.35676187 0.35055625 0.39897433] | BEST Val RMSE 0.2985 @ update 53
# [0710] Train RMSE [0.3607109  0.35766926 0.39780942] | Val RMSE [0.35705435 0.3563254  0.39777228] | BEST Val RMSE 0.2985 @ update 53
# [0720] Train RMSE [0.3566069  0.35506594 0.3984832 ] | Val RMSE [0.3528522  0.3539446  0.39834666] | BEST Val RMSE 0.2985 @ update 53
# [0730] Train RMSE [0.3553647  0.35059232 0.4014809 ] | Val RMSE [0.35131836 0.348848   0.40117207] | BEST Val RMSE 0.2985 @ update 53
# [0740] Train RMSE [0.33790848 0.35281998 0.39760667] | Val RMSE [0.3337409  0.35031492 0.39775285] | BEST Val RMSE 0.2985 @ update 53
# [0750] Train RMSE [0.32254133 0.35472244 0.38890097] | Val RMSE [0.31834182 0.3516982  0.38964477] | BEST Val RMSE 0.2985 @ update 53
# [0760] Train RMSE [0.32471323 0.36120713 0.39040095] | Val RMSE [0.3204095  0.35815468 0.3908928 ] | BEST Val RMSE 0.2985 @ update 53
# [0770] Train RMSE [0.32209516 0.36680764 0.3863428 ] | Val RMSE [0.3183111  0.36416423 0.38729784] | BEST Val RMSE 0.2985 @ update 53
# [0780] Train RMSE [0.3190579  0.36820078 0.38808057] | Val RMSE [0.31531554 0.36631665 0.3886409 ] | BEST Val RMSE 0.2985 @ update 53
# [0790] Train RMSE [0.32640696 0.37014207 0.3872483 ] | Val RMSE [0.32297394 0.36840937 0.38754797] | BEST Val RMSE 0.2985 @ update 53
# [0800] Train RMSE [0.3212574  0.36231455 0.3795662 ] | Val RMSE [0.31761533 0.36084232 0.38005185] | BEST Val RMSE 0.2985 @ update 53
# [0810] Train RMSE [0.34518018 0.37750602 0.3844558 ] | Val RMSE [0.34093317 0.37523633 0.3851152 ] | BEST Val RMSE 0.2985 @ update 53
# [0820] Train RMSE [0.3474386  0.3903421  0.37864852] | Val RMSE [0.34261644 0.38810846 0.37912706] | BEST Val RMSE 0.2985 @ update 53
# [0830] Train RMSE [0.34184617 0.3842988  0.37745738] | Val RMSE [0.33751106 0.3818762  0.3781939 ] | BEST Val RMSE 0.2985 @ update 53
# [0840] Train RMSE [0.33491063 0.37842566 0.38043636] | Val RMSE [0.33057338 0.37628806 0.3813168 ] | BEST Val RMSE 0.2985 @ update 53
# [0850] Train RMSE [0.3318528  0.37231156 0.37934935] | Val RMSE [0.32819498 0.3701743  0.38021845] | BEST Val RMSE 0.2985 @ update 53
# [0860] Train RMSE [0.34767297 0.36686048 0.379157  ] | Val RMSE [0.3438027  0.36479795 0.38031563] | BEST Val RMSE 0.2985 @ update 53
# [0870] Train RMSE [0.34953892 0.36181557 0.37329522] | Val RMSE [0.34523207 0.35944572 0.37444845] | BEST Val RMSE 0.2985 @ update 53
# [0880] Train RMSE [0.3443139  0.36059156 0.37473574] | Val RMSE [0.3402421  0.35856852 0.37577957] | BEST Val RMSE 0.2985 @ update 53
# [0890] Train RMSE [0.3591201  0.35579887 0.38535923] | Val RMSE [0.35511044 0.35368818 0.38623267] | BEST Val RMSE 0.2985 @ update 53
# [0900] Train RMSE [0.37108025 0.34759316 0.3816076 ] | Val RMSE [0.3673937  0.34552088 0.3825915 ] | BEST Val RMSE 0.2985 @ update 53
# [0910] Train RMSE [0.3627083  0.34574938 0.37581125] | Val RMSE [0.3590208 0.34418   0.3772298] | BEST Val RMSE 0.2985 @ update 53
# [0920] Train RMSE [0.360681   0.34598893 0.3774729 ] | Val RMSE [0.3564516 0.3444833 0.3790288] | BEST Val RMSE 0.2985 @ update 53
# [0930] Train RMSE [0.34293276 0.33808884 0.3762644 ] | Val RMSE [0.33861956 0.33656254 0.37766716] | BEST Val RMSE 0.2985 @ update 53
# [0940] Train RMSE [0.34531227 0.34173256 0.3738855 ] | Val RMSE [0.3414459  0.3409129  0.37564155] | BEST Val RMSE 0.2985 @ update 53
# [0950] Train RMSE [0.3473347 0.3502759 0.3764433] | Val RMSE [0.34340212 0.350176   0.3781793 ] | BEST Val RMSE 0.2985 @ update 53
# [0960] Train RMSE [0.3503308  0.35408986 0.3769488 ] | Val RMSE [0.34665397 0.35421884 0.37864873] | BEST Val RMSE 0.2985 @ update 53
# [0970] Train RMSE [0.37546173 0.35225904 0.38081726] | Val RMSE [0.37234524 0.3523287  0.38243568] | BEST Val RMSE 0.2985 @ update 53
# [0980] Train RMSE [0.36699283 0.35114926 0.37871373] | Val RMSE [0.3642724  0.35129648 0.38044754] | BEST Val RMSE 0.2985 @ update 53
# [0990] Train RMSE [0.34819236 0.33477318 0.36643347] | Val RMSE [0.3459068  0.33504727 0.3683286 ] | BEST Val RMSE 0.2985 @ update 53
# [1000] Train RMSE [0.3584722  0.33289027 0.36572012] | Val RMSE [0.35609373 0.33282223 0.36738345] | BEST Val RMSE 0.2985 @ update 53
# [1010] Train RMSE [0.3539317  0.33401072 0.36014906] | Val RMSE [0.35212833 0.33277252 0.3618884 ] | BEST Val RMSE 0.2985 @ update 53
# [1020] Train RMSE [0.36738557 0.3341765  0.36278433] | Val RMSE [0.36596   0.332719  0.3647476] | BEST Val RMSE 0.2985 @ update 53
# [1030] Train RMSE [0.370018   0.33554733 0.35856012] | Val RMSE [0.36867115 0.33430737 0.36054698] | BEST Val RMSE 0.2985 @ update 53
# [1040] Train RMSE [0.36763388 0.34360918 0.35680312] | Val RMSE [0.36616892 0.34231    0.3588949 ] | BEST Val RMSE 0.2985 @ update 53
# [1050] Train RMSE [0.36274278 0.35086206 0.34755537] | Val RMSE [0.36165762 0.34919938 0.35011095] | BEST Val RMSE 0.2985 @ update 53
# [1060] Train RMSE [0.3669365  0.35008386 0.35247675] | Val RMSE [0.36583215 0.34862396 0.35495797] | BEST Val RMSE 0.2985 @ update 53
# [1070] Train RMSE [0.3706523  0.35293475 0.36003983] | Val RMSE [0.36931467 0.3513925  0.36270398] | BEST Val RMSE 0.2985 @ update 53
# [1080] Train RMSE [0.36316478 0.34315172 0.36081204] | Val RMSE [0.3616546  0.34235466 0.36358455] | BEST Val RMSE 0.2985 @ update 53
# [1090] Train RMSE [0.36601967 0.35168728 0.36381283] | Val RMSE [0.36454672 0.35043812 0.36652145] | BEST Val RMSE 0.2985 @ update 53
# [1100] Train RMSE [0.36992827 0.35331288 0.36372238] | Val RMSE [0.3684139  0.35224664 0.36641696] | BEST Val RMSE 0.2985 @ update 53
# [1110] Train RMSE [0.373772   0.347404   0.36554706] | Val RMSE [0.3721882  0.34655255 0.36809623] | BEST Val RMSE 0.2985 @ update 53
# [1120] Train RMSE [0.37160602 0.34102193 0.36385605] | Val RMSE [0.36989734 0.34033757 0.36661252] | BEST Val RMSE 0.2985 @ update 53
# [1130] Train RMSE [0.35970995 0.3365317  0.36328688] | Val RMSE [0.35769767 0.3358277  0.3656167 ] | BEST Val RMSE 0.2985 @ update 53
# [1140] Train RMSE [0.35110736 0.33948162 0.35829848] | Val RMSE [0.3486453  0.33899558 0.36053306] | BEST Val RMSE 0.2985 @ update 53
# [1150] Train RMSE [0.34831518 0.3493421  0.35039616] | Val RMSE [0.34589028 0.34848964 0.3527723 ] | BEST Val RMSE 0.2985 @ update 53
# [1160] Train RMSE [0.34025782 0.34971866 0.3452477 ] | Val RMSE [0.3380407  0.34882912 0.34784696] | BEST Val RMSE 0.2985 @ update 53
# [1170] Train RMSE [0.35022554 0.34838438 0.34628516] | Val RMSE [0.34838971 0.3478217  0.34885594] | BEST Val RMSE 0.2985 @ update 53
# [1180] Train RMSE [0.35579127 0.3464466  0.3513521 ] | Val RMSE [0.3542725  0.34595907 0.353641  ] | BEST Val RMSE 0.2985 @ update 53
# [1190] Train RMSE [0.35061044 0.3445666  0.3453084 ] | Val RMSE [0.3493014  0.34371933 0.3476862 ] | BEST Val RMSE 0.2985 @ update 53
# [1200] Train RMSE [0.34738863 0.35091677 0.35437343] | Val RMSE [0.34608367 0.34997374 0.3566839 ] | BEST Val RMSE 0.2985 @ update 53
# [1210] Train RMSE [0.34299582 0.36033657 0.35965213] | Val RMSE [0.3414312  0.35916987 0.3620482 ] | BEST Val RMSE 0.2985 @ update 53
# [1220] Train RMSE [0.3431866 0.350821  0.3589544] | Val RMSE [0.34176302 0.3503876  0.3615008 ] | BEST Val RMSE 0.2985 @ update 53
# [1230] Train RMSE [0.3509144  0.34560895 0.3582577 ] | Val RMSE [0.34937766 0.34518436 0.3608233 ] | BEST Val RMSE 0.2985 @ update 53
# [1240] Train RMSE [0.35983804 0.34880245 0.35946518] | Val RMSE [0.3585397  0.34838584 0.36214486] | BEST Val RMSE 0.2985 @ update 53
# [1250] Train RMSE [0.36157942 0.34886092 0.35956955] | Val RMSE [0.36057588 0.3476777  0.36224702] | BEST Val RMSE 0.2985 @ update 53
# [1260] Train RMSE [0.36465767 0.35212088 0.36424544] | Val RMSE [0.36410904 0.35094815 0.36717856] | BEST Val RMSE 0.2985 @ update 53
# [1270] Train RMSE [0.37324303 0.35190016 0.37121567] | Val RMSE [0.37284166 0.3508988  0.37417054] | BEST Val RMSE 0.2985 @ update 53
# [1280] Train RMSE [0.38046983 0.3550269  0.37083593] | Val RMSE [0.38021746 0.35354087 0.37383485] | BEST Val RMSE 0.2985 @ update 53
# [1290] Train RMSE [0.38797525 0.35745618 0.37636155] | Val RMSE [0.3880697 0.3559499 0.3793503] | BEST Val RMSE 0.2985 @ update 53
# [1300] Train RMSE [0.38385245 0.36048883 0.3736928 ] | Val RMSE [0.38378313 0.35879385 0.3766762 ] | BEST Val RMSE 0.2985 @ update 53
# [1310] Train RMSE [0.38304168 0.36613616 0.3791949 ] | Val RMSE [0.3829234  0.3644374  0.38183314] | BEST Val RMSE 0.2985 @ update 53
# [1320] Train RMSE [0.38413998 0.3633115  0.38000152] | Val RMSE [0.38393137 0.36220258 0.38268965] | BEST Val RMSE 0.2985 @ update 53
# [1330] Train RMSE [0.39199862 0.37167627 0.3830443 ] | Val RMSE [0.39171436 0.37044474 0.3856651 ] | BEST Val RMSE 0.2985 @ update 53
# [1340] Train RMSE [0.38641512 0.3617884  0.3785131 ] | Val RMSE [0.38614777 0.36081433 0.38146016] | BEST Val RMSE 0.2985 @ update 53
# [1350] Train RMSE [0.3897378  0.3632832  0.37944394] | Val RMSE [0.3894757  0.36271074 0.38260362] | BEST Val RMSE 0.2985 @ update 53
# [1360] Train RMSE [0.38774553 0.37407026 0.383713  ] | Val RMSE [0.3873128  0.37375632 0.38683942] | BEST Val RMSE 0.2985 @ update 53
# [1370] Train RMSE [0.38493562 0.36221766 0.37956315] | Val RMSE [0.38449222 0.36240655 0.3826342 ] | BEST Val RMSE 0.2985 @ update 53
# [1380] Train RMSE [0.385917   0.36468366 0.3866037 ] | Val RMSE [0.38532996 0.36484218 0.389705  ] | BEST Val RMSE 0.2985 @ update 53
# [1390] Train RMSE [0.38683355 0.37446588 0.39238593] | Val RMSE [0.38606727 0.37390077 0.3953476 ] | BEST Val RMSE 0.2985 @ update 53
# [1400] Train RMSE [0.38577574 0.38383523 0.3964016 ] | Val RMSE [0.38484207 0.38276848 0.39927158] | BEST Val RMSE 0.2985 @ update 53
# [1410] Train RMSE [0.38491565 0.38924614 0.3997528 ] | Val RMSE [0.38398352 0.3881302  0.40268046] | BEST Val RMSE 0.2985 @ update 53
# [1420] Train RMSE [0.39253238 0.40738404 0.4079249 ] | Val RMSE [0.39159355 0.40561536 0.41021103] | BEST Val RMSE 0.2985 @ update 53
# [1430] Train RMSE [0.4030084  0.4209945  0.42721155] | Val RMSE [0.40186724 0.41975656 0.42866963] | BEST Val RMSE 0.2985 @ update 53
# [1440] Train RMSE [0.4014877  0.39955163 0.41554514] | Val RMSE [0.40026388 0.3989192  0.4176164 ] | BEST Val RMSE 0.2985 @ update 53
# [1450] Train RMSE [0.39827082 0.40903145 0.41593212] | Val RMSE [0.39708093 0.4077557  0.41780704] | BEST Val RMSE 0.2985 @ update 53
# [1460] Train RMSE [0.39465675 0.41919848 0.4217787 ] | Val RMSE [0.39372152 0.4177735  0.42348728] | BEST Val RMSE 0.2985 @ update 53
# [1470] Train RMSE [0.39048037 0.43449792 0.43077496] | Val RMSE [0.38947567 0.4323101  0.43213594] | BEST Val RMSE 0.2985 @ update 53
# [1480] Train RMSE [0.39094493 0.4412518  0.4389971 ] | Val RMSE [0.38983196 0.43945777 0.44012374] | BEST Val RMSE 0.2985 @ update 53
# [1490] Train RMSE [0.388362   0.43918324 0.43270695] | Val RMSE [0.387414   0.43717477 0.43380958] | BEST Val RMSE 0.2985 @ update 53
# [1500] Train RMSE [0.38902125 0.44451955 0.44902655] | Val RMSE [0.38814655 0.44264713 0.449817  ] | BEST Val RMSE 0.2985 @ update 53
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[22], line 237
#     234     return rmse, mae, r2, a_real_np, y_np
#     236 # Load best model
# --> 237 checkpoint = torch.load(save_path)
#     238 actor.load_state_dict(checkpoint["actor_state_dict"])
#     239 critic.load_state_dict(checkpoint["critic_state_dict"])
#
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\torch\serialization.py:1524, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1516                 return _load(
#    1517                     opened_zipfile,
#    1518                     map_location,
#    (...)
#    1521                     **pickle_load_args,
#    1522                 )
#    1523             except pickle.UnpicklingError as e:
# -> 1524                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1525         return _load(
#    1526             opened_zipfile,
#    1527             map_location,
#    (...)
#    1530             **pickle_load_args,
#    1531         )
#    1532 if mmap:
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL sklearn.preprocessing._data.StandardScaler was not an allowed global by default. Please use `torch.serialization.add_safe_globals([sklearn.preprocessing._data.StandardScaler])` or the `torch.serialization.safe_globals([sklearn.preprocessing._data.StandardScaler])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %% [markdown]
# Device: cuda
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0001, clip=0.1, epochs=5
# Test RMSE: [0.6550997 0.7870014 0.595848 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0001, clip=0.1, epochs=10
# Test RMSE: [0.62875676 0.77620864 0.5924772 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0001, clip=0.2, epochs=5
# Test RMSE: [0.6448393  0.7714192  0.56400216]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0001, clip=0.2, epochs=10
# Test RMSE: [0.615239  0.7709177 0.5598636]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0001, clip=0.3, epochs=5
# Test RMSE: [0.6190845  0.7657865  0.55996597]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0001, clip=0.3, epochs=10
# Test RMSE: [0.63388467 0.7540485  0.5646412 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0002, clip=0.1, epochs=5
# Test RMSE: [0.63284653 0.78322244 0.60900295]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0002, clip=0.1, epochs=10
# Test RMSE: [0.63094705 0.7783213  0.5664742 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0002, clip=0.2, epochs=5
# Test RMSE: [0.6281557  0.77506346 0.5866226 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0002, clip=0.2, epochs=10
# Test RMSE: [0.63627183 0.76337785 0.5586819 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0002, clip=0.3, epochs=5
# Test RMSE: [0.60253435 0.76957303 0.5877005 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0002, clip=0.3, epochs=10
# Test RMSE: [0.62294036 0.7779541  0.5564842 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0005, clip=0.1, epochs=5
# Test RMSE: [0.64735615 0.7733592  0.5972116 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0005, clip=0.1, epochs=10
# Test RMSE: [0.6260279 0.7660749 0.5670783]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0005, clip=0.2, epochs=5
# Test RMSE: [0.63330054 0.7789745  0.5792878 ]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0005, clip=0.2, epochs=10
# Test RMSE: [0.6306568  0.7678817  0.55583405]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0005, clip=0.3, epochs=5
# Test RMSE: [0.6112697  0.7574683  0.56477314]
#
# ---------------------------------------
# TUNING: lrA=3e-05, lrC=0.0005, clip=0.3, epochs=10
# Test RMSE: [0.6266853  0.75339216 0.55591124]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0001, clip=0.1, epochs=5
# Test RMSE: [0.6361086  0.7779389  0.55705595]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0001, clip=0.1, epochs=10
# Test RMSE: [0.6248713 0.7857344 0.5518592]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0001, clip=0.2, epochs=5
# Test RMSE: [0.6319785  0.7874034  0.57259345]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0001, clip=0.2, epochs=10
# Test RMSE: [0.61684823 0.78182507 0.5568857 ]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0001, clip=0.3, epochs=5
# Test RMSE: [0.66053367 0.7825911  0.58586854]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0001, clip=0.3, epochs=10
# Test RMSE: [0.65022683 0.77593845 0.5411307 ]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0002, clip=0.1, epochs=5
# Test RMSE: [0.6280518  0.78028536 0.54930156]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0002, clip=0.1, epochs=10
# Test RMSE: [0.6141983 0.7794185 0.5375695]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0002, clip=0.2, epochs=5
# Test RMSE: [0.63105047 0.78221494 0.582285  ]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0002, clip=0.2, epochs=10
# Test RMSE: [0.6286195  0.7707063  0.54596364]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0002, clip=0.3, epochs=5
# Test RMSE: [0.6249386  0.7580577  0.55916065]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0002, clip=0.3, epochs=10
# Test RMSE: [0.61147994 0.77853405 0.5452023 ]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0005, clip=0.1, epochs=5
# Test RMSE: [0.65170497 0.7614278  0.5510371 ]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0005, clip=0.1, epochs=10
# Test RMSE: [0.6265958  0.77964085 0.5435662 ]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0005, clip=0.2, epochs=5
# Test RMSE: [0.6266493  0.77703816 0.55975777]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0005, clip=0.2, epochs=10
# Test RMSE: [0.6220934  0.7772656  0.54833394]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0005, clip=0.3, epochs=5
# Test RMSE: [0.6090624  0.76296526 0.53402096]
#
# ---------------------------------------
# TUNING: lrA=0.0001, lrC=0.0005, clip=0.3, epochs=10
# Test RMSE: [0.61619866 0.76610583 0.5110914 ]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0001, clip=0.1, epochs=5
# Test RMSE: [0.6362322  0.80945426 0.5121469 ]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0001, clip=0.1, epochs=10
# Test RMSE: [0.61285484 0.81027716 0.5288254 ]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0001, clip=0.2, epochs=5
# Test RMSE: [0.6109574  0.7906666  0.55770916]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0001, clip=0.2, epochs=10
# Test RMSE: [0.6083591 0.8166217 0.5510426]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0001, clip=0.3, epochs=5
# Test RMSE: [0.61800873 0.78505886 0.552752  ]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0001, clip=0.3, epochs=10
# Test RMSE: [0.60198826 0.77099955 0.522584  ]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0002, clip=0.1, epochs=5
# Test RMSE: [0.6269578  0.7846514  0.55403584]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0002, clip=0.1, epochs=10
# Test RMSE: [0.6308408  0.7806722  0.59126323]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0002, clip=0.2, epochs=5
# Test RMSE: [0.6439235  0.7785489  0.54559726]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0002, clip=0.2, epochs=10
# Test RMSE: [0.64051396 0.78434664 0.50478816]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0002, clip=0.3, epochs=5
# Test RMSE: [0.6264731  0.79039466 0.5399864 ]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0002, clip=0.3, epochs=10
# Test RMSE: [0.6238988  0.78430444 0.5388912 ]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0005, clip=0.1, epochs=5
# Test RMSE: [0.5823307  0.7820617  0.53306514]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0005, clip=0.1, epochs=10
# Test RMSE: [0.63632697 0.78742653 0.53950846]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0005, clip=0.2, epochs=5
# Test RMSE: [0.63835096 0.77250063 0.5230584 ]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0005, clip=0.2, epochs=10
# Test RMSE: [0.6151925 0.7776928 0.5753905]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0005, clip=0.3, epochs=5
# Test RMSE: [0.6002628 0.7728203 0.5685843]
#
# ---------------------------------------
# TUNING: lrA=0.0003, lrC=0.0005, clip=0.3, epochs=10
# Test RMSE: [0.6136116  0.7701638  0.50971496]
#
# ===== BEST HYPERPARAMETERS =====
# lr_actor 0.0001
# lr_critic 0.0005
# clip_eps 0.3
# ppo_epochs 10
# rmse [0.61619866 0.76610583 0.5110914 ]
# mean_rmse 0.6311320066452026
#
# ===== FINAL TRAINING =====
#
# FINAL TEST RMSE (scaled): [0.59677345 0.7754475  0.52641016]
#
# FINAL TEST RMSE (kg/ha): [0.46883917 0.84615296 0.35595876]

# %%
with torch.no_grad():
    mu_test, _ = actor(X_test)
    a_test_scaled = torch.tanh(mu_test)

# Move to CPU and convert to numpy
a_test_scaled_np = a_test_scaled.cpu().numpy()
FERT_MIN_np = FERT_MIN.cpu().numpy()
FERT_MAX_np = FERT_MAX.cpu().numpy()

# Map to real fertilizer units
a_test_real = FERT_MIN_np + (a_test_scaled_np + 1) / 2 * (FERT_MAX_np - FERT_MIN_np)

# y_test to numpy
y_test_np = y_test.cpu().numpy()

# Check min/max
for i, fert in enumerate(["UREA", "DAP", "MOP"]):
    print(f"{fert}: Predicted min={a_test_real[:, i].min():.2f}, max={a_test_real[:, i].max():.2f}, "
          f"True min={y_test_np[:, i].min():.2f}, max={y_test_np[:, i].max():.2f}")
# Out:
# UREA: Predicted min=0.00, max=3.27, True min=-0.50, max=3.27
# DAP: Predicted min=0.50, max=4.03, True min=0.54, max=3.62
# MOP: Predicted min=0.53, max=3.35, True min=0.42, max=3.34

# %%
import numpy as np

# a_test_real and y_test_np are both in real fertilizer units
rmse_real = np.sqrt(((a_test_real - y_test_np)**2).mean(axis=0))

# Range of each fertilizer
ranges = y_test_np.max(axis=0) - y_test_np.min(axis=0)

# NRMSE
nrmse = rmse_real / ranges

# Print
for i, fert in enumerate(["UREA", "DAP", "MOP"]):
    print(f"{fert} NRMSE: {nrmse[i]*100:.2f}%")
# Out:
# UREA NRMSE: 10.22%
# DAP NRMSE: 14.39%
# MOP NRMSE: 15.35%

# %%
import pandas as pd

# Clip predictions to valid ranges (optional)
a_test_real_clipped = np.clip(a_test_real, FERT_MIN.cpu().numpy(), FERT_MAX.cpu().numpy())

# Take first 10 test samples
n_samples = 10
data = {
    "UREA_true": y_test_np[:n_samples, 0],
    "UREA_pred": a_test_real_clipped[:n_samples, 0],
    "DAP_true": y_test_np[:n_samples, 1],
    "DAP_pred": a_test_real_clipped[:n_samples, 1],
    "MOP_true": y_test_np[:n_samples, 2],
    "MOP_pred": a_test_real_clipped[:n_samples, 2],
}

df_compare = pd.DataFrame(data)
print(df_compare)
# Out:
#    UREA_true  UREA_pred  DAP_true  DAP_pred  MOP_true  MOP_pred
# 0      -0.07   1.176400      1.74  1.917760      1.34  1.587893
# 1       2.21   2.680528      0.54  0.514001      1.34  1.327913
# 2       1.31   1.341422      3.62  2.115071      3.34  1.764749
# 3       1.26   1.675797      1.74  2.452708      1.34  2.727881
# 4       2.21   1.302182      3.62  2.297139      3.34  1.941122
# 5       2.50   2.728569      2.89  1.743195      3.34  3.214435
# 6       2.50   2.533513      2.89  1.931699      3.34  3.127984
# 7       1.18   1.197248      1.63  1.705541      1.67  1.672146
# 8       1.26   1.367010      1.74  1.644759      1.67  1.688908
# 9       1.18   1.230884      1.63  1.710360      1.67  1.725221

# %%
import numpy as np

# Compute RMSE per fertilizer (action)
rmse_per_action = np.sqrt(((a_test_real - y_test_np) ** 2).mean(axis=0))

for i, fert in enumerate(["UREA", "DAP", "MOP"]):
    print(f"{fert} RMSE: {rmse_per_action[i]:.4f} kg/ropani")
# Out:
# UREA RMSE: 0.3852 kg/ropani
# DAP RMSE: 0.4432 kg/ropani
# MOP RMSE: 0.4482 kg/ropani
