# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/crop_recommendation.csv")

# %%
df.head(5)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# df["label"].nunique()
df["label"].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
count_crop = df["label"].unique()
unique = len(count_crop)
print("Number of crops available is" ,unique,".")
# Out:
# Number of crops available is 22 .

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
print("Minimum Nitrogen Value(kg/ha):" ,df["N"].min())
print("Maximum Nitrogen Value(kg/ha):" ,df["N"].max())
print("Minimum Phosphorus Value(kg/ha):" ,df["P"].min())
print("Maximum Nitrogen Value(kg/ha):" ,df["N"].max())
print("Minimum Potassium Value(kg/ha):" ,df["K"].min())
print("Maximum Potassium Value(kg/ha):" ,df["K"].max())
print("Maximum Phosphorus Value(kg/ha):" ,df["P"].max())
# Out:
# Minimum Nitrogen Value(kg/ha): 0
# Maximum Nitrogen Value(kg/ha): 140
# Minimum Phosphorus Value(kg/ha): 5
# Maximum Nitrogen Value(kg/ha): 140
# Minimum Potassium Value(kg/ha): 5
# Maximum Potassium Value(kg/ha): 205
# Maximum Phosphorus Value(kg/ha): 145

# %% [markdown]
# Converting float to integer

# %%
float_columns = df.select_dtypes(include=['float64']).columns
df[float_columns] = df[float_columns].astype(int)
df
# Out:
#         N   P   K  temperature  humidity  ph  rainfall   label
# 0      90  42  43           20        82   6       202    rice
# 1      85  58  41           21        80   7       226    rice
# 2      60  55  44           23        82   7       263    rice
# 3      74  35  40           26        80   6       242    rice
# 4      78  42  42           20        81   7       262    rice
# ...   ...  ..  ..          ...       ...  ..       ...     ...
# 2195  107  34  32           26        66   6       177  coffee
# 2196   99  15  27           27        56   6       127  coffee
# 2197  118  33  30           24        67   6       173  coffee
# 2198  117  32  34           26        52   6       127  coffee
# 2199  104  18  30           23        60   6       140  coffee
#
# [2200 rows x 8 columns]

# %%
df
# Out:
#         N   P   K  temperature  humidity  ph  rainfall   label
# 0      90  42  43           20        82   6       202    rice
# 1      85  58  41           21        80   7       226    rice
# 2      60  55  44           23        82   7       263    rice
# 3      74  35  40           26        80   6       242    rice
# 4      78  42  42           20        81   7       262    rice
# ...   ...  ..  ..          ...       ...  ..       ...     ...
# 2195  107  34  32           26        66   6       177  coffee
# 2196   99  15  27           27        56   6       127  coffee
# 2197  118  33  30           24        67   6       173  coffee
# 2198  117  32  34           26        52   6       127  coffee
# 2199  104  18  30           23        60   6       140  coffee
#
# [2200 rows x 8 columns]

# %%
df["label"] = df["label"].map({
    "rice": 1,
    "maize": 2,
    "chickpea": 3,
    "kidneybeans": 4,
    "pigeonpeas": 5,
    "mothbeans": 6,
    "mungbean": 7,
    "blackgram": 8,
    "lentil": 9,
    "pomegranate": 10,
    "banana": 11,
    "mango": 12,
    "grapes": 13,
    "watermelon": 14,
    "muskmelon": 15,
    "apple": 16,
    "orange": 17,
    "papaya": 18,
    "coconut": 19,
    "cotton": 20,
    "jute": 21,
    "coffee": 22
})
df
# Out:
#         N   P   K  temperature  humidity  ph  rainfall  label
# 0      90  42  43           20        82   6       202      1
# 1      85  58  41           21        80   7       226      1
# 2      60  55  44           23        82   7       263      1
# 3      74  35  40           26        80   6       242      1
# 4      78  42  42           20        81   7       262      1
# ...   ...  ..  ..          ...       ...  ..       ...    ...
# 2195  107  34  32           26        66   6       177     22
# 2196   99  15  27           27        56   6       127     22
# 2197  118  33  30           24        67   6       173     22
# 2198  117  32  34           26        52   6       127     22
# 2199  104  18  30           23        60   6       140     22
#
# [2200 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# Check Features Ranges

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.120000    70.976364
# std      36.917334    32.985883    50.647931     5.062696    22.263427
# min       0.000000     5.000000     5.000000     8.000000    14.000000
# 25%      21.000000    28.000000    20.000000    22.000000    60.000000
# 50%      37.000000    51.000000    32.000000    25.000000    80.000000
# 75%      84.250000    68.000000    49.000000    28.000000    89.000000
# max     140.000000   145.000000   205.000000    43.000000    99.000000
#
#                 ph     rainfall        label
# count  2200.000000  2200.000000  2200.000000
# mean      5.950000   102.970000    11.500000
# std       0.824395    54.948949     6.345731
# min       3.000000    20.000000     1.000000
# 25%       5.000000    64.000000     6.000000
# 50%       6.000000    94.000000    11.500000
# 75%       6.000000   124.000000    17.000000
# max       9.000000   298.000000    22.000000

# %% [markdown]
# ### Observations from the Data
# Wide Ranges of Feature Values:
#
# N: 0 to 140 (range = 140)
# P: 5 to 145 (range = 140)
# K: 5 to 205 (range = 200)
# Rainfall: 20 to 298 (range = 278)
# These features have significantly different ranges, which makes scaling important for models sensitive to feature magnitudes (e.g., neural networks, KNN).
# Smaller Ranges:
#
# Temperature: 8 to 43 (range = 35)
# Humidity: 14 to 99 (range = 85)
# pH: 3 to 9 (range = 6)
# While these features have smaller ranges compared to N, P, K, and Rainfall, they still vary enough to require scaling to bring them into a uniform range.
# Target Variable (Label):
#
# The label is categorical (1 to 22) and doesn’t need scaling. It should remain as an integer or encoded format for modeling.
# Standard Deviation:
#
# Features like K (std = 50.65) and Rainfall (std = 54.95) have high standard deviations compared to others. This confirms that these features can dominate learning without scaling.

# %% [markdown]
# ### Recommended Scaling Method

# %% [markdown]
# ##### Min-Max Scaling
# Best suited here because:
# It preserves the original distribution of the data.
# It scales features to a fixed range [0, 1], ensuring uniformity for algorithms like neural networks and reinforcement learning.

# %% [markdown]
# ##### ALternative
# Standardization (Z-score Scaling)
# Alternative if the dataset contains outliers or if models like SVM or PCA are planned, as it scales data to have a mean of 0 and a standard deviation of 1.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Identify Outliers Using Statistical Methods
# IQR (Interquartile Range) Method
# Outliers are typically defined as values lying outside
#
# 𝑄
# 1
# −
# 1.5
# ×
# 𝐼
# 𝑄
# 𝑅
# ,
# 𝑄
# 3
# +
# 1.5
# ×
# 𝐼
# 𝑄
# 𝑅
# ]
# [Q1−1.5×IQR,Q3+1.5×IQR], where:
#
#
# Q1 = 25th percentile
# Q3 = 75th percentile
#
#
# IQR=Q3−Q1

# %%
# Compute IQR for each feature
Q1 = df[["N", "P", "K", "temperature", "humidity", "ph", "rainfall"]].quantile(0.25)
Q3 = df[["N", "P", "K", "temperature", "humidity", "ph", "rainfall"]].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers = ((df[["N", "P", "K", "temperature", "humidity", "ph", "rainfall"]] < (Q1 - 1.5 * IQR)) | 
            (df[["N", "P", "K", "temperature", "humidity", "ph", "rainfall"]] > (Q3 + 1.5 * IQR)))
print(outliers.sum())  # Count of outliers per feature
# Out:
# N                0
# P              138
# K              200
# temperature     76
# humidity        56
# ph              66
# rainfall        97
# dtype: int64

# %% [markdown]
# ### Blox plot to visualize outliers

# %%
# Plot boxplots for each feature
plt.figure(figsize=(12, 8))
for i, feature in enumerate(["N", "P", "K", "temperature", "humidity", "ph", "rainfall"], 1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=df[feature])
    plt.title(feature)

plt.tight_layout()
plt.show()

# %%
# ....Q1 = df.quantile(0.25)
# Q3 = df.quantile(0.75)
# IQR = Q3 - Q1

# # Cap outliers
# df_capped = df.copy()
# for col in ["P", "K", "temperature", "humidity", "ph", "rainfall"]:
#     lower_bound = Q1[col] - 1.5 * IQR[col]
#     upper_bound = Q3[col] + 1.5 * IQR[col]
#     df_capped[col] = df_capped[col].clip(lower_bound, upper_bound)

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.120000    70.976364
# std      36.917334    32.985883    50.647931     5.062696    22.263427
# min       0.000000     5.000000     5.000000     8.000000    14.000000
# 25%      21.000000    28.000000    20.000000    22.000000    60.000000
# 50%      37.000000    51.000000    32.000000    25.000000    80.000000
# 75%      84.250000    68.000000    49.000000    28.000000    89.000000
# max     140.000000   145.000000   205.000000    43.000000    99.000000
#
#                 ph     rainfall        label
# count  2200.000000  2200.000000  2200.000000
# mean      5.950000   102.970000    11.500000
# std       0.824395    54.948949     6.345731
# min       3.000000    20.000000     1.000000
# 25%       5.000000    64.000000     6.000000
# 50%       6.000000    94.000000    11.500000
# 75%       6.000000   124.000000    17.000000
# max       9.000000   298.000000    22.000000

# %% [markdown]
# Using Standarization

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler instance
scaler = StandardScaler()

# Standardize the features
df_scaled = scaler.fit_transform(df[["N", "P", "K", "temperature", "humidity", "ph", "rainfall"]])

# Convert the scaled values back to a DataFrame
df_scaled = pd.DataFrame(df_scaled, columns=["N", "P", "K", "temperature", "humidity", "ph", "rainfall"])

# If you want to include the label column back:
df_scaled["label"] = df["label"]

# %%
df_scaled.describe()
# Out:
#                   N             P             K   temperature      humidity  \
# count  2.200000e+03  2.200000e+03  2.200000e+03  2.200000e+03  2.200000e+03
# mean  -1.033517e-16  5.167584e-17 -5.167584e-17 -1.937844e-16  3.100550e-16
# std    1.000227e+00  1.000227e+00  1.000227e+00  1.000227e+00  1.000227e+00
# min   -1.369636e+00 -1.466498e+00 -8.521355e-01 -3.382367e+00 -2.559773e+00
# 25%   -8.006682e-01 -7.690712e-01 -5.559060e-01 -6.164126e-01 -4.931343e-01
# 50%   -3.671690e-01 -7.164472e-02 -3.189225e-01 -2.370818e-02  4.054042e-01
# 75%    9.130086e-01  4.438444e-01  1.680429e-02  5.689962e-01  8.097466e-01
# max    2.423483e+00  2.778707e+00  3.097591e+00  3.532518e+00  1.259016e+00
#
#                  ph      rainfall        label
# count  2.200000e+03  2.200000e+03  2200.000000
# mean  -2.067033e-16  2.583792e-17    11.500000
# std    1.000227e+00  1.000227e+00     6.345731
# min   -3.579195e+00 -1.510290e+00     1.000000
# 25%   -1.152622e+00 -7.093650e-01     6.000000
# 50%    6.066433e-02 -1.632795e-01    11.500000
# 75%    6.066433e-02  3.828059e-01    17.000000
# max    3.700524e+00  3.550101e+00    22.000000

# %% [markdown]
# ## Implementing DQN

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from collections import deque
import random

# %%
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)  # First layer expects 'state_size' inputs
        self.fc2 = nn.Linear(128, 128)         # Hidden layer
        self.fc3 = nn.Linear(128, action_size)  # Output layer (Q-values for each action)

    def forward(self, state):
        x = torch.relu(self.fc1(state))  # Apply ReLU after the first layer
        x = torch.relu(self.fc2(x))      # Apply ReLU after the second layer
        x = self.fc3(x)                  # Output layer (Q-values for each action)
        return x

# %% [markdown]
# ##### Setup the DQN Algorithm

# %%
class CropEnvironment:
    def __init__(self, data):
        self.data = data
        self.current_step = 0

    def reset(self):
        self.current_step = 0
        return self.data[self.current_step]

    def step(self, action):
        self.current_step += 1
        if self.current_step >= len(self.data):
            done = True
            self.current_step = 0  # Reset for next episode
        else:
            done = False
        next_state = self.data[self.current_step]
        reward = self.get_reward(action)
        return next_state, reward, done, {}

    def get_reward(self, action):
        # Custom reward function
        if action == 2:
            return 1  # Example: action 2 yields a better outcome
        elif action == 0:
            return -1  # Negative reward for action 0
        else:
            return -0.5  # Slight penalty for action 1

# %% [markdown]
# #### Training Loop

# %%
def store_experience(state, action, reward, next_state, done):
    memory.append((state, action, reward, next_state, done))

def sample_batch(batch_size):
    return random.sample(memory, batch_size)

# %%
learning_rate = 1e-3
gamma = 0.99
epsilon = 1.0  # Start with full exploration
min_epsilon = 0.1  # Minimum epsilon value
epsilon_decay = 0.995  # Epsilon decay rate
batch_size = 64
memory_capacity = 10000

# Initialize the DQN and target networks
state_size = 8  # Number of features in the state (example)
action_size = 3  # Example: 3 possible actions (adjust as needed)
dqn = DQN(state_size, action_size)
target_network = DQN(state_size, action_size)
target_network.load_state_dict(dqn.state_dict())  # Initialize target network with same weights
optimizer = optim.Adam(dqn.parameters(), lr=learning_rate)

# Initialize the environment and experience replay buffer
env = CropEnvironment(df_scaled.values)  # Assuming df_scaled is your scaled data
memory = deque(maxlen=memory_capacity)

# %%
def train_dqn(episodes=1000):
    global epsilon
    for episode in range(episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            # Exploration-exploitation trade-off
            if np.random.rand() < epsilon:
                action = np.random.choice(action_size)  # Random action (exploration)
            else:
                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
                q_values = dqn(state_tensor)
                action = torch.argmax(q_values).item()  # Best action (exploitation)

            next_state, reward, done, _ = env.step(action)

            # Store experience
            store_experience(state, action, reward, next_state, done)

            state = next_state
            total_reward += reward

            # Train from experience replay
            if len(memory) > batch_size:
                batch = sample_batch(batch_size)
                states, actions, rewards, next_states, dones = zip(*batch)
                states = torch.tensor(states, dtype=torch.float32)
                next_states = torch.tensor(next_states, dtype=torch.float32)
                actions = torch.tensor(actions)
                rewards = torch.tensor(rewards)
                dones = torch.tensor(dones)

                q_values = dqn(states).gather(1, actions.unsqueeze(1))  # Q-value for selected action
                next_q_values = target_network(next_states).max(1)[0].detach()  # Max Q-value for next state
                target = rewards + (gamma * next_q_values * (1 - dones.float()))  # Bellman equation

                # Compute loss and backpropagate
                loss = nn.MSELoss()(q_values.squeeze(), target)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        # Update the target network periodically
        if episode % 10 == 0:
            target_network.load_state_dict(dqn.state_dict())

        # Decay epsilon after each episode
        epsilon = max(epsilon * epsilon_decay, min_epsilon)

        print(f"Episode {episode}, Total Reward: {total_reward}, Epsilon: {epsilon}")
        
train_dqn()
# Out:
# Episode 0, Total Reward: -430.5, Epsilon: 0.995
# Episode 1, Total Reward: -294.0, Epsilon: 0.990025
# Episode 2, Total Reward: -317.5, Epsilon: 0.985074875
# Episode 3, Total Reward: -341.5, Epsilon: 0.9801495006250001
# Episode 4, Total Reward: -342.5, Epsilon: 0.9752487531218751
# Episode 5, Total Reward: -326.0, Epsilon: 0.9703725093562657
# Episode 6, Total Reward: -393.5, Epsilon: 0.9655206468094844
# Episode 7, Total Reward: -179.0, Epsilon: 0.960693043575437
# Episode 8, Total Reward: -329.0, Epsilon: 0.9558895783575597
# Episode 9, Total Reward: -279.5, Epsilon: 0.9511101304657719
# Episode 10, Total Reward: -263.0, Epsilon: 0.946354579813443
# Episode 11, Total Reward: -261.0, Epsilon: 0.9416228069143757
# Episode 12, Total Reward: -121.0, Epsilon: 0.9369146928798039
# Episode 13, Total Reward: -195.0, Epsilon: 0.9322301194154049
# Episode 14, Total Reward: -193.5, Epsilon: 0.9275689688183278
# Episode 15, Total Reward: -144.5, Epsilon: 0.9229311239742362
# Episode 16, Total Reward: -204.5, Epsilon: 0.918316468354365
# Episode 17, Total Reward: -213.5, Epsilon: 0.9137248860125932
# Episode 18, Total Reward: -154.0, Epsilon: 0.9091562615825302
# Episode 19, Total Reward: -139.5, Epsilon: 0.9046104802746175
# Episode 20, Total Reward: -47.5, Epsilon: 0.9000874278732445
# Episode 21, Total Reward: -176.5, Epsilon: 0.8955869907338783
# Episode 22, Total Reward: -67.0, Epsilon: 0.8911090557802088
# Episode 23, Total Reward: -49.5, Epsilon: 0.8866535105013078
# Episode 24, Total Reward: -75.5, Epsilon: 0.8822202429488013
# Episode 111, Total Reward: 754.0, Epsilon: 0.5704072587541458
# Episode 112, Total Reward: 767.0, Epsilon: 0.567555222460375
# Episode 113, Total Reward: 665.5, Epsilon: 0.5647174463480732
# Episode 114, Total Reward: 760.0, Epsilon: 0.5618938591163328
# Episode 115, Total Reward: 746.5, Epsilon: 0.5590843898207511
# Episode 116, Total Reward: 763.0, Epsilon: 0.5562889678716474
# Episode 117, Total Reward: 709.5, Epsilon: 0.5535075230322891
# Episode 118, Total Reward: 796.5, Epsilon: 0.5507399854171277
# Episode 119, Total Reward: 774.5, Epsilon: 0.547986285490042
# Episode 120, Total Reward: 758.0, Epsilon: 0.5452463540625918
# Episode 121, Total Reward: 730.0, Epsilon: 0.5425201222922789
# Episode 122, Total Reward: 766.0, Epsilon: 0.5398075216808175
# Episode 123, Total Reward: 801.0, Epsilon: 0.5371084840724134
# Episode 124, Total Reward: 844.5, Epsilon: 0.5344229416520513
# Episode 125, Total Reward: 807.5, Epsilon: 0.531750826943791
# Episode 126, Total Reward: 869.0, Epsilon: 0.5290920728090721
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[167], line 54
#      50         epsilon = max(epsilon * epsilon_decay, min_epsilon)
#      52         print(f"Episode {episode}, Total Reward: {total_reward}, Epsilon: {epsilon}")
# ---> 54 train_dqn()
#
# Cell In[167], line 41, in train_dqn(episodes)
#      39 # Compute loss and backpropagate
#      40 loss = nn.MSELoss()(q_values.squeeze(), target)
# ---> 41 optimizer.zero_grad()
#      42 loss.backward()
#      43 optimizer.step()
#
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\torch\_compile.py:24, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def inner(*args, **kwargs):
#      22     import torch._dynamo
# ---> 24     return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\torch\_dynamo\eval_frame.py:489, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     487     dynamo_config_ctx.__enter__()
#     488 try:
# --> 489     return fn(*args, **kwargs)
#     490 finally:
#     491     set_eval_frame(prior)
#
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\torch\optim\optimizer.py:815, in Optimizer.zero_grad(self, set_to_none)
#     812 else:
#     813     per_device_and_dtype_grads = None
# --> 815 with torch.autograd.profiler.record_function(self._zero_grad_profile_name):
#     816     for group in self.param_groups:
#     817         for p in group['params']:
#
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\torch\autograd\profiler.py:605, in record_function.__enter__(self)
#     604 def __enter__(self):
# --> 605     self.record = torch.ops.profiler._record_function_enter_new(
#     606         self.name, self.args
#     607     )
#     608     return self
#
# File c:\Users\Acer\.conda\envs\nlp-env\Lib\site-packages\torch\_ops.py:755, in OpOverloadPacket.__call__(self, *args, **kwargs)
#     750 def __call__(self, *args, **kwargs):
#     751     # overloading __call__ to ensure torch.ops.foo.bar()
#     752     # is still callable from JIT
#     753     # We save the function ptr as the `op` attribute on
#     754     # OpOverloadPacket to access it here.
# --> 755     return self._op(*args, **(kwargs or {}))
#
# KeyboardInterrupt:
